# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../Datasets/googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df = df.fillna(0)

df.Price = df.Price.replace('[$]','',regex= True)

df.Price = df.Price.replace('[Everyone]','0',regex= True)

df.Price = df.Price.astype(float)

df.Installs = df.Installs.replace('[+,]','',regex=True)

df.Installs = df.Installs.replace('Free','0',regex=True)

df.Installs = df.Installs.astype(int)

df.drop([10472], inplace = True)

df.Reviews = df.Reviews.astype(int)

# %% [markdown]
# # BEAUTY

# %%
bty = df[df.Category == "BEAUTY"]
bty.head()
# Out:
#                                                    App Category  Rating  \
# 98                          Hush - Beauty for Everyone   BEAUTY     4.7
# 99                      ipsy: Makeup, Beauty, and Tips   BEAUTY     4.9
# 100                    Natural recipes for your beauty   BEAUTY     4.7
# 101  BestCam Selfie-selfie, beauty camera, photo ed...   BEAUTY     3.9
# 102                         Mirror - Zoom & Exposure -   BEAUTY     3.9
#
#      Reviews                Size  Installs  Type  Price Content Rating  \
# 98     18900                 17M    500000  Free    0.0       Everyone
# 99     49790                 14M   1000000  Free    0.0       Everyone
# 100     1150                9.8M    100000  Free    0.0       Everyone
# 101     1739                 21M    500000  Free    0.0       Everyone
# 102    32090  Varies with device   1000000  Free    0.0       Everyone
#
#      Genres      Last Updated         Current Ver         Android Ver
# ...

# %%
bty.Installs = bty.Installs.replace('[+,]','',regex = True)

bty.Reviews = bty.Reviews.astype('int64')
bty.Installs = bty.Installs.astype('int64')

# %%
lowbty = bty[((bty.Rating >4.5) & (bty.Reviews<10000)) | (bty.Installs<=10000)]
lowbty
# Out:
#                                                 App Category  Rating  Reviews  \
# 100                 Natural recipes for your beauty   BEAUTY     4.7     1150
# 104                         Hairstyles step by step   BEAUTY     4.6     4369
# 106                           Tie - Always be happy   BEAUTY     4.7      964
# 108                            Prom MakeUp Tutorial   BEAUTY     4.8      104
# 111                         Colors of white in Urdu   BEAUTY     4.5       36
# 114                         Eyes Makeup Beauty Tips   BEAUTY     4.2       30
# 115                               Photo Editor 2018   BEAUTY     4.5      134
# 116               Step By Step Eyes Makeup Tutorial   BEAUTY     4.4       74
# 121                Haircut Tutorials/Haircut Videos   BEAUTY     4.6       38
# 127                        Facial Wrinkle Reduction   BEAUTY     4.6      184
# 128                                   Makeup Videos   BEAUTY     3.8        9
# ...

# %%
for i in lowbty.index:
    bty=bty.drop([i], axis = 0)

# %%
bty = bty[bty.Rating >= 4.0]

# %%
bty = bty.sort_values('Rating', ascending=False)

topbty = bty.sort_values('Installs', ascending=False)

# %%
top_bty = pd.pivot_table(data = topbty , index =['App','Category'], values = ['Rating','Installs'])
top_bty
# Out:
#                                                              Installs  Rating
# App                                                Category
# Beauty Camera - Selfie Camera                      BEAUTY    10000000     4.0
# Beauty Selfie Camera                               BEAUTY      500000     4.2
# Beauty Tips - Beauty Tips in Sinhala               BEAUTY       50000     4.4
# Best Hairstyles step by step                       BEAUTY     5000000     4.5
# Discover Color                                     BEAUTY      100000     4.0
# Dresses Ideas & Fashions +3000                     BEAUTY      100000     4.5
# Filters for B Live                                 BEAUTY      500000     4.4
# Filters for Selfie                                 BEAUTY     1000000     4.3
# Girls Hairstyles                                   BEAUTY      500000     4.1
# Hush - Beauty for Everyone                         BEAUTY      500000     4.7
# ...

# %%
top_bty = top_bty.sort_values('Installs',ascending=False)

top_bty = top_bty.reset_index()

# %%
beauty = top_bty.drop('Installs',axis = 1)

beauty
# Out:
#                                                   App Category  Rating
# 0                       Beauty Camera - Selfie Camera   BEAUTY     4.0
# 1                        Best Hairstyles step by step   BEAUTY     4.5
# 2                                  Filters for Selfie   BEAUTY     4.3
# 3                                         Ulta Beauty   BEAUTY     4.7
# 4   Sephora: Skin Care, Beauty Makeup & Fragrance ...   BEAUTY     4.5
# 5                                       Selfie Camera   BEAUTY     4.2
# 6              Mirror Camera (Mirror + Selfie Camera)   BEAUTY     4.1
# 7                      ipsy: Makeup, Beauty, and Tips   BEAUTY     4.9
# 8                                Beauty Selfie Camera   BEAUTY     4.2
# 9                          Hush - Beauty for Everyone   BEAUTY     4.7
# 10                                 Filters for B Live   BEAUTY     4.4
# 11                                   Girls Hairstyles   BEAUTY     4.1
# ...

# %% [markdown]
# # SOCIAL

# %%
soc = df[df['Category'] == 'SOCIAL']

# %%
soc.Installs = soc.Installs.replace('[+,]','',regex = True)

soc.Installs = soc.Installs.astype('int64')
soc.Reviews = soc.Reviews.astype('int64')

# %%
low = soc[((soc['Rating'] > 4.0) & (soc['Reviews'] <= 1000)) | (soc['Installs'] < 10000)]

# %%
for i in low.index:
    soc = soc.drop([i], axis = 0)

# %%
soc = soc[soc.Rating >= 4.0]

# %%
topinstsocial = soc.sort_values('Installs',ascending = False)

# %%
top_social = pd.pivot_table(data = topinstsocial,index =['App','Category'], values=['Rating','Installs'])

# %%
top_social = top_social.sort_values('Installs',ascending=False)

# %%
top_social = top_social.drop('Installs',axis = 1)

# %%
social = top_social.reset_index().head(20)
social
# Out:
#                                                  App Category  Rating
# 0                                          Instagram   SOCIAL     4.5
# 1                                            Google+   SOCIAL     4.2
# 2                                           Facebook   SOCIAL     4.1
# 3                                           Snapchat   SOCIAL     4.0
# 4                                      Facebook Lite   SOCIAL     4.3
# 5                                          Pinterest   SOCIAL     4.6
# 6                     Tik Tok - including musical.ly   SOCIAL     4.4
# 7                                             Tumblr   SOCIAL     4.4
# 8                            BIGO LIVE - Live Stream   SOCIAL     4.4
# 9                     Badoo - Free Chat & Dating App   SOCIAL     4.3
# 10                      Tango - Live Video Broadcast   SOCIAL     4.3
# 11                                          LinkedIn   SOCIAL     4.2
# ...

# %% [markdown]
# # PRODUCTIVITY

# %%
pro = df[df['Category'] == 'PRODUCTIVITY']

# %%
pro.Installs = pro.Installs.replace('[+,]','',regex = True)
pro.Installs = pro.Installs.astype('int64')
pro.Reviews = pro.Reviews.astype('int64')

# %%
lowpro = pro[((pro.Rating >= 4.5) & (pro.Reviews < 1000)) | (pro.Installs <= 10000)]

# %%
for i in lowpro.index:
    pro = pro.drop([i],axis = 0)

# %%
pro = pro[(pro.Rating >= 4.0)]

# %%
topinstpro = pro.sort_values('Installs',ascending=False)

# %%
topinstpro = topinstpro.drop_duplicates()

# %%
top_productivity = pd.pivot_table(data = topinstpro , index =['App','Category'], values = ['Rating','Installs'])

# %%
top_productivity = top_productivity.sort_values('Installs', ascending=False)

# %%
top_productivity = top_productivity.drop('Installs', axis =1)

# %%
top_productivity = top_productivity.reset_index()

# %%
productivity = top_productivity.head(20)

# %%
productivity
# Out:
#                                                   App      Category  Rating
# 0                                        Google Drive  PRODUCTIVITY     4.4
# 1                                             Dropbox  PRODUCTIVITY     4.4
# 2                                         Cloud Print  PRODUCTIVITY     4.1
# 3                                      Microsoft Word  PRODUCTIVITY     4.5
# 4                                     Google Calendar  PRODUCTIVITY     4.2
# 5                                       Google Slides  PRODUCTIVITY     4.2
# 6                                   SwiftKey Keyboard  PRODUCTIVITY     4.5
# 7                                Microsoft PowerPoint  PRODUCTIVITY     4.5
# 8                             ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 9                       ES File Explorer File Manager  PRODUCTIVITY     4.6
# 10    Evernote – Organizer, Planner for Notes & Memos  PRODUCTIVITY     4.6
# ...

# %% [markdown]
# # PERSONALIZATION

# %%
per = df[df.Category == 'PERSONALIZATION']

# %%
per.Installs = per.Installs.replace('[+,]','', regex = True)
per.Installs = per.Installs.astype('int64')
per.Reviews = per.Reviews.astype('int64')

# %%
lowper = per[((per.Rating >= 4.5) & (per.Reviews <= 100)) | (per.Installs < 10000) ]

# %%
for i in lowper.index:
    per = per.drop([i],axis = 0)

# %%
topper = per[per.Rating > 4.0]

# %%
topinstper = topper.sort_values('Installs',ascending=False)

# %%
top_per = pd.pivot_table(data = topinstper ,index =['App','Category'], values= ['Rating','Installs'])

# %%
top_per = top_per.sort_values('Installs',ascending=False)

# %%
top_personalization = top_per.drop('Installs', axis = 1)

# %%
top_personalization = top_personalization.reset_index()

# %%
personalization = top_personalization.head(20)

# %%
personalization
# Out:
#                                                  App         Category  Rating
# 0                        Backgrounds HD (Wallpapers)  PERSONALIZATION     4.6
# 1      CM Launcher 3D - Theme, Wallpapers, Efficient  PERSONALIZATION     4.6
# 2   GO Keyboard - Emoticon keyboard, Free Theme, GIF  PERSONALIZATION     4.4
# 3                      ZEDGE™ Ringtones & Wallpapers  PERSONALIZATION     4.6
# 4   GO Launcher - 3D parallax Themes & HD Wallpapers  PERSONALIZATION     4.5
# 5        APUS Launcher - Theme, Wallpaper, Hide Apps  PERSONALIZATION     4.5
# 6      Parallel Space - Multiple accounts & Two face  PERSONALIZATION     4.6
# 7                     Hola Launcher- Theme,Wallpaper  PERSONALIZATION     4.5
# 8                                      Nova Launcher  PERSONALIZATION     4.6
# 9                                     ZenUI Launcher  PERSONALIZATION     4.7
# 10                       Yandex Browser with Protect  PERSONALIZATION     4.5
# ...

# %% [markdown]
# # HOUSE_AND_HOME

# %%
hah = df[df.Category == 'HOUSE_AND_HOME']

# %%
hah.Installs = hah.Installs.replace('[+,]','',regex = True)
hah.Installs = hah.Installs.astype('int64')
hah.Reviews = hah.Reviews.astype('int64')

# %%
lowhah = hah[((hah.Rating >= 4.5) & (hah.Reviews <= 500)) | (hah.Installs < 1000)]

# %%
for i in lowhah.index:
    hah = hah.drop([i], axis = 0)

# %%
tophah = hah[hah.Rating > 4.0]

# %%
tophah = pd.pivot_table(data = tophah ,index =['App','Category'], values = ['Installs','Rating'])

# %%
top_housing = tophah.sort_values('Installs', ascending=False)

# %%
top_housing = top_housing.drop('Installs', axis = 1)

# %%
top_housing = top_housing.reset_index()

# %%
housing = top_housing.head(20)
housing
# Out:
#                                                   App        Category  Rating
# 0                         Houzz Interior Design Ideas  HOUSE_AND_HOME     4.6
# 1                        Trulia Real Estate & Rentals  HOUSE_AND_HOME     4.5
# 2   Zillow: Find Houses for Sale & Apartments for ...  HOUSE_AND_HOME     4.5
# 3    Realtor.com Real Estate: Homes for Sale and Rent  HOUSE_AND_HOME     4.5
# 4                      Trulia Rent Apartments & Homes  HOUSE_AND_HOME     4.4
# 5                         Alfred Home Security Camera  HOUSE_AND_HOME     4.5
# 6                      DaBang - Rental Homes in Korea  HOUSE_AND_HOME     4.4
# 7                      Real Estate sale & rent Trovit  HOUSE_AND_HOME     4.1
# 8                    Zumper - Apartment Rental Finder  HOUSE_AND_HOME     4.4
# 9                                  Redfin Real Estate  HOUSE_AND_HOME     4.6
# 10  591 housing transactions - renting houses, mid...  HOUSE_AND_HOME     4.1
# ...

# %% [markdown]
# # MAPS_AND_NAVIGATION

# %%
man = df[df.Category == 'MAPS_AND_NAVIGATION']

# %%
man.Installs = man.Installs.replace('[+,]','',regex = True)
man.Installs = man.Installs.astype('int64')
man.Reviews = man.Reviews.astype('int64')

# %%
lowman = man[((man.Rating >= 4.5) & (man.Reviews <= 500)) | (man.Installs < 10000)]

# %%
for i in lowman.index:
    man = man.drop([i], axis = 0)

# %%
man = man[man.Rating >= 4.0]

# %%
top_man = pd.pivot_table(data = man ,index =['App','Category'], values = ['Rating', 'Installs'])

# %%
top_man = top_man.sort_values('Installs', ascending=False)

# %%
top_man = top_man.reset_index()

# %%
top_man = top_man.head(20)

# %%
maps = top_man.drop(['Installs'], axis = 1)

# %%
maps
# Out:
#                                                   App             Category  \
# 0   Waze - GPS, Maps, Traffic Alerts & Live Naviga...  MAPS_AND_NAVIGATION
# 1                                                Uber  MAPS_AND_NAVIGATION
# 2                 GPS Navigation & Offline Maps Sygic  MAPS_AND_NAVIGATION
# 3                                 Free GPS Navigation  MAPS_AND_NAVIGATION
# 4                       TomTom GPS Navigation Traffic  MAPS_AND_NAVIGATION
# 5                   Subway Terminator: Smarter Subway  MAPS_AND_NAVIGATION
# 6                                        DB Navigator  MAPS_AND_NAVIGATION
# 7        MapQuest: Directions, Maps, GPS & Navigation  MAPS_AND_NAVIGATION
# 8                                             Compass  MAPS_AND_NAVIGATION
# 9             Moovit: Bus Time & Train Time Live Info  MAPS_AND_NAVIGATION
# 10  Yahoo! transit guide free timetable, operation...  MAPS_AND_NAVIGATION
# ...

# %% [markdown]
# # FAMILY

# %%
fam = df[df.Category == 'FAMILY']
fam.head()
# Out:
#                                App Category  Rating  Reviews  \
# 2014                  YouTube Kids   FAMILY     4.5   470694
# 2015                    Candy Bomb   FAMILY     4.4    42145
# 2016                        ROBLOX   FAMILY     4.5  4449910
# 2017  Jewels Crush- Match 3 Puzzle   FAMILY     4.4    14774
# 2018              Coloring & Learn   FAMILY     4.4    12753
#
#                     Size   Installs  Type  Price Content Rating  \
# 2014  Varies with device   50000000  Free    0.0       Everyone
# 2015                 20M   10000000  Free    0.0       Everyone
# 2016                 67M  100000000  Free    0.0   Everyone 10+
# 2017                 19M    1000000  Free    0.0       Everyone
# 2018                 51M    5000000  Free    0.0       Everyone
#
#                             Genres    Last Updated   Current Ver   Android Ver
# 2014   Entertainment;Music & Video  August 3, 2018        3.43.3    4.1 and up
# ...

# %%
fam1 = fam[fam.Installs > 1000000]
fam1.head()
# Out:
#                    App Category  Rating  Reviews                Size  \
# 2014      YouTube Kids   FAMILY     4.5   470694  Varies with device
# 2015        Candy Bomb   FAMILY     4.4    42145                 20M
# 2016            ROBLOX   FAMILY     4.5  4449910                 67M
# 2018  Coloring & Learn   FAMILY     4.4    12753                 51M
# 2019           Mahjong   FAMILY     4.5    33983                 22M
#
#        Installs  Type  Price Content Rating                        Genres  \
# 2014   50000000  Free    0.0       Everyone   Entertainment;Music & Video
# 2015   10000000  Free    0.0       Everyone            Casual;Brain Games
# 2016  100000000  Free    0.0   Everyone 10+  Adventure;Action & Adventure
# 2018    5000000  Free    0.0       Everyone        Educational;Creativity
# 2019    5000000  Free    0.0       Everyone            Puzzle;Brain Games
#
#         Last Updated   Current Ver   Android Ver
# 2014  August 3, 2018        3.43.3    4.1 and up
# ...

# %%
f1 = pd.pivot_table(data = fam1,index =['App','Category'], values=['Rating'])
family =f1.sort_values('Rating',ascending=False).head(20).reset_index()
family
# Out:
#                                                App Category  Rating
# 0                                         Eternium   FAMILY     4.8
# 1                    Vlogger Go Viral - Tuber Game   FAMILY     4.8
# 2                      PewDiePie's Tuber Simulator   FAMILY     4.8
# 3     No. Color - Color by Number, Number Coloring   FAMILY     4.8
# 4                              Narcos: Cartel Wars   FAMILY     4.7
# 5                      Dog Run - Pet Dog Simulator   FAMILY     4.7
# 6                                   Darkness Rises   FAMILY     4.7
# 7                                  Ayat - Al Quran   FAMILY     4.7
# 8         Sandbox - Color by Number Coloring Pages   FAMILY     4.7
# 9             Anime Love Story Games: ✨Shadowtime✨   FAMILY     4.7
# 10                               Angry Birds Match   FAMILY     4.7
# 11                  Duolingo: Learn Languages Free   FAMILY     4.7
# 12                          Bubbu – My Virtual Pet   FAMILY     4.7
# ...

# %%
print(fam1.groupby('Genres')['Type'].value_counts())
Type_fam = fam1.groupby('Genres')['Type'].value_counts().unstack()
Type_fam.head()
# Out:
# Genres                                 Type
# Action;Action & Adventure              Free     8
# Adventure;Action & Adventure           Free     5
# Adventure;Education                    Free     2
# Arcade;Action & Adventure              Free     4
#                                        Paid     2
# Board;Action & Adventure               Free     1
# Board;Brain Games                      Free     1
# Card;Action & Adventure                Free     1
# Casual                                 Free    44
# Casual;Action & Adventure              Free    14
# Casual;Brain Games                     Free     1
# Casual;Creativity                      Free     4
# Casual;Music & Video                   Free     2
# Casual;Pretend Play                    Free    16
# Education                              Free    10
# Education;Brain Games                  Free     1
# Education;Creativity                   Free     1
# Education;Education                    Free     6
# ...

# %%
fam_ins = (fam.Installs > fam.Installs.mean())
fam_rev = (fam.Reviews > fam.Reviews.median())
fam_Prc = (fam.Price > 0)

# %%
fam_ins_rev = fam_ins & fam_rev

# %%
family1 = fam[fam_ins_rev].sort_values('Rating',ascending=False)
family1.head(20)
# Out:
#                                                 App Category  Rating  \
# 4073                                       Eternium   FAMILY     4.8
# 6707                  Vlogger Go Viral - Tuber Game   FAMILY     4.8
# 2040   No. Color - Color by Number, Number Coloring   FAMILY     4.8
# 4799                    PewDiePie's Tuber Simulator   FAMILY     4.8
# 6993       Sandbox - Color by Number Coloring Pages   FAMILY     4.7
# 5437                         Bubbu – My Virtual Pet   FAMILY     4.7
# 8433                                    Idle Heroes   FAMILY     4.7
# 2029                    Dog Run - Pet Dog Simulator   FAMILY     4.7
# 2216                 Duolingo: Learn Languages Free   FAMILY     4.7
# 8439                 Duolingo: Learn Languages Free   FAMILY     4.7
# 2091                    Dog Run - Pet Dog Simulator   FAMILY     4.7
# 2056                 Duolingo: Learn Languages Free   FAMILY     4.7
# 6578                                       Township   FAMILY     4.6
# ...

# %%
fam_ins_rev_Prc = fam_ins & fam_rev & fam_Prc

# %%
fam[fam_ins_rev_Prc]
# Out:
#             App Category  Rating  Reviews                Size  Installs  Type  \
# 2241  Minecraft   FAMILY     4.5  2376564  Varies with device  10000000  Paid
# 4347  Minecraft   FAMILY     4.5  2375336  Varies with device  10000000  Paid
#
#       Price Content Rating                     Genres   Last Updated  \
# 2241   6.99   Everyone 10+  Arcade;Action & Adventure  July 24, 2018
# 4347   6.99   Everyone 10+  Arcade;Action & Adventure  July 24, 2018
#
#      Current Ver         Android Ver
# 2241     1.5.2.1  Varies with device
# 4347     1.5.2.1  Varies with device

# %% [markdown]
# # FINANCE

# %%
fin = df[df.Category == 'FINANCE']
fin.head()
# Out:
#                     App Category  Rating  Reviews                Size  \
# 1048             K PLUS  FINANCE     4.4   124424  Varies with device
# 1049        ING Banking  FINANCE     4.4    39041  Varies with device
# 1050  Citibanamex Movil  FINANCE     3.6    52306                 42M
# 1051    The postal bank  FINANCE     3.7    36718  Varies with device
# 1052        KTB Netbank  FINANCE     3.8    42644                 19M
#
#       Installs  Type  Price Content Rating   Genres    Last Updated  \
# 1048  10000000  Free    0.0       Everyone  Finance   June 26, 2018
# 1049   1000000  Free    0.0       Everyone  Finance  August 3, 2018
# 1050   5000000  Free    0.0       Everyone  Finance   July 27, 2018
# 1051   5000000  Free    0.0       Everyone  Finance   July 16, 2018
# 1052   5000000  Free    0.0       Everyone  Finance   June 28, 2018
#
#              Current Ver         Android Ver
# 1048               4.6.0          4.2 and up
# ...

# %%
fin1 = fin[fin.Installs > 1000000]
fin1.head()
# Out:
#                     App Category  Rating  Reviews                Size  \
# 1048             K PLUS  FINANCE     4.4   124424  Varies with device
# 1050  Citibanamex Movil  FINANCE     3.6    52306                 42M
# 1051    The postal bank  FINANCE     3.7    36718  Varies with device
# 1052        KTB Netbank  FINANCE     3.8    42644                 19M
# 1053    Mobile Bancomer  FINANCE     4.2   278082                 70M
#
#       Installs  Type  Price Content Rating   Genres   Last Updated  \
# 1048  10000000  Free    0.0       Everyone  Finance  June 26, 2018
# 1050   5000000  Free    0.0       Everyone  Finance  July 27, 2018
# 1051   5000000  Free    0.0       Everyone  Finance  July 16, 2018
# 1052   5000000  Free    0.0       Everyone  Finance  June 28, 2018
# 1053  10000000  Free    0.0       Everyone  Finance  July 30, 2018
#
#              Current Ver         Android Ver
# 1048               4.6.0          4.2 and up
# 1050              20.1.0          5.0 and up
# ...

# %%
finance = pd.pivot_table(data = fin1, index =['App','Category'], values=['Rating'])
finance = finance.sort_values('Rating',ascending=False).head(20).reset_index()
finance
# Out:
#                                                   App Category  Rating
# 0                                        Credit Karma  FINANCE     4.7
# 1                                              Nubank  FINANCE     4.7
# 2                      Money Manager Expense & Budget  FINANCE     4.6
# 3                                        MetaTrader 4  FINANCE     4.6
# 4   Stocks, Forex, Bitcoin, Ethereum: Portfolio & ...  FINANCE     4.6
# 5                                 Capital One® Mobile  FINANCE     4.6
# 6                                     Discover Mobile  FINANCE     4.6
# 7                                        Chase Mobile  FINANCE     4.6
# 8                                               İşCep  FINANCE     4.5
# 9                                         USAA Mobile  FINANCE     4.5
# 10    Western Union US - Send Money Transfers Quickly  FINANCE     4.5
# 11                                     Bank of Brazil  FINANCE     4.5
# ...

# %%
print(fin1.groupby('Genres')['Type'].value_counts())
Type_fin = fin1.groupby('Genres')['Type'].value_counts().unstack()
Type_fin
# Out:
# Genres   Type
# Finance  Free    48
# Name: Type, dtype: int64
# Type     Free
# Genres
# Finance    48

# %%
fin_ins = (fin.Installs > fin.Installs.mean())
fin_rev = (fin.Reviews > fin.Reviews.median())

fin_ins_rev = fin_ins & fin_rev

fin[fin_ins_rev].sort_values('Rating',ascending=False).head(20)
# Out:
#                                                     App Category  Rating  \
# 1114                                       Credit Karma  FINANCE     4.7
# 1060                                             Nubank  FINANCE     4.7
# 7455                                       Credit Karma  FINANCE     4.7
# 1074                                       Credit Karma  FINANCE     4.7
# 1126                                       MetaTrader 4  FINANCE     4.6
# 1077                                Capital One® Mobile  FINANCE     4.6
# 1131  Stocks, Forex, Bitcoin, Ethereum: Portfolio & ...  FINANCE     4.6
# 1167                                    Discover Mobile  FINANCE     4.6
# 1099                     Money Manager Expense & Budget  FINANCE     4.6
# 1169                                Capital One® Mobile  FINANCE     4.6
# 1173                                       Chase Mobile  FINANCE     4.6
# 1088                                     Bank of Brazil  FINANCE     4.5
# ...

# %%
fin_p = fin[fin.Price > 0]
fin_p.sort_values('Installs',ascending=False)
# Out:
#                                   App Category  Rating  Reviews  Size  \
# 6886                   My Budget Book  FINANCE     4.7    19784  7.3M
# 5356                I Am Rich Premium  FINANCE     4.1     1867  4.7M
# 5361           I am Rich Premium Plus  FINANCE     4.6      459  2.0M
# 10540    Ray Financial Calculator Pro  FINANCE     4.0       67  2.4M
# 5369                        I am Rich  FINANCE     4.3      180  3.8M
# 5359               I am rich(premium)  FINANCE     3.5      472  965k
# 5364   I am rich (Most expensive app)  FINANCE     4.1      129  2.7M
# 5373               I AM RICH PRO PLUS  FINANCE     4.0       36   41M
# 5911     Ba Financial Calculator plus  FINANCE     4.4       31  206k
# 5358                       I am Rich!  FINANCE     3.8       93   22M
# 5914      BA Pro Financial Calculator  FINANCE     2.4       36  9.4M
# 5912   Financial Calculator BA Chien.  FINANCE     4.2       23  954k
# ...

# %% [markdown]
# # NEWS_AND_MAGAZINES

# %%
new = df[df.Category == 'NEWS_AND_MAGAZINES']
new.head()
# Out:
#                                                     App            Category  \
# 3715  Fox News – Breaking News, Live Video & News Al...  NEWS_AND_MAGAZINES
# 3716                     NEW - Read Newspaper, News 24h  NEWS_AND_MAGAZINES
# 3717                           BaBe + - Indonesian News  NEWS_AND_MAGAZINES
# 3718                                         daily News  NEWS_AND_MAGAZINES
# 3719                                           BBC News  NEWS_AND_MAGAZINES
#
#       Rating  Reviews                Size  Installs  Type  Price  \
# 3715     4.5   249919  Varies with device  10000000  Free    0.0
# 3716     4.4   158196  Varies with device  10000000  Free    0.0
# 3717     4.3    42624                 16M   1000000  Free    0.0
# 3718     4.5    26411                 26M   1000000  Free    0.0
# 3719     4.3   296781  Varies with device  10000000  Free    0.0
#
#      Content Rating            Genres    Last Updated         Current Ver  \
# ...

# %%
new1 = new[new.Installs > 1000000]
new1.head()
# Out:
#                                                     App            Category  \
# 3715  Fox News – Breaking News, Live Video & News Al...  NEWS_AND_MAGAZINES
# 3716                     NEW - Read Newspaper, News 24h  NEWS_AND_MAGAZINES
# 3719                                           BBC News  NEWS_AND_MAGAZINES
# 3722                      Le Monde, the continuous news  NEWS_AND_MAGAZINES
# 3724                       CNN Breaking US & World News  NEWS_AND_MAGAZINES
#
#       Rating  Reviews                Size  Installs  Type  Price  \
# 3715     4.5   249919  Varies with device  10000000  Free    0.0
# 3716     4.4   158196  Varies with device  10000000  Free    0.0
# 3719     4.3   296781  Varies with device  10000000  Free    0.0
# 3722     4.2    83558  Varies with device   5000000  Free    0.0
# 3724     4.0   293080                 25M  10000000  Free    0.0
#
#      Content Rating            Genres    Last Updated         Current Ver  \
# ...

# %%
NEWS = pd.pivot_table(data = new1, index =['App','Category'], values=['Rating'])
NEWS = NEWS.sort_values('Rating',ascending=False).head(20).reset_index()
NEWS
# Out:
#                                                   App            Category  \
# 0                                        The Guardian  NEWS_AND_MAGAZINES
# 1         Topbuzz: Breaking News, Videos & Funny GIFs  NEWS_AND_MAGAZINES
# 2                                      Podcast Addict  NEWS_AND_MAGAZINES
# 3   Reddit: Social News, Trending Memes & Funny Vi...  NEWS_AND_MAGAZINES
# 4                     Pulse Nabd - World News, Urgent  NEWS_AND_MAGAZINES
# 5   Fox News – Breaking News, Live Video & News Al...  NEWS_AND_MAGAZINES
# 6                                              Pocket  NEWS_AND_MAGAZINES
# 7               Opera News - Trending news and videos  NEWS_AND_MAGAZINES
# 8    NewsDog - Latest News, Breaking News, Local News  NEWS_AND_MAGAZINES
# 9                      NEW - Read Newspaper, News 24h  NEWS_AND_MAGAZINES
# 10                       Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 11                                      News Republic  NEWS_AND_MAGAZINES
# ...

# %%
print(new1.groupby('Genres')['Type'].value_counts())
Type_news = new1.groupby('Genres')['Type'].value_counts().unstack()
Type_news
# Out:
# Genres            Type
# News & Magazines  Free    58
# Name: Type, dtype: int64
# Type              Free
# Genres
# News & Magazines    58

# %%
new_ins = (new.Installs > new.Installs.mean())
new_rev = (new.Reviews > new.Reviews.median())

new_ins_rev = new_ins & new_rev

new[new_ins_rev].sort_values('Rating',ascending=False).head(20)
# Out:
#                                                    App            Category  \
# 3755                      Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 3767                      Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 3819                      Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 3729  Dailyhunt (Newshunt) - Latest News, Viral Videos  NEWS_AND_MAGAZINES
# 3739                                           Twitter  NEWS_AND_MAGAZINES
# 3796                                           Twitter  NEWS_AND_MAGAZINES
# 4115                                           Twitter  NEWS_AND_MAGAZINES
# 3736                                       Google News  NEWS_AND_MAGAZINES
# 3765                                       Google News  NEWS_AND_MAGAZINES
# 3816                                       Google News  NEWS_AND_MAGAZINES
# 9844                                       Google News  NEWS_AND_MAGAZINES
#
# ...

# %% [markdown]
# # VIDEO_PLAYERS

# %%
video = df[df.Category == 'VIDEO_PLAYERS']
video.head()
# Out:
#                             App       Category  Rating   Reviews  \
# 3665                    YouTube  VIDEO_PLAYERS     4.3  25655305
# 3666  All Video Downloader 2018  VIDEO_PLAYERS     4.3      7557
# 3667           Video Downloader  VIDEO_PLAYERS     4.2     59089
# 3668            HD Video Player  VIDEO_PLAYERS     4.3      1551
# 3669         Iqiyi (for tablet)  VIDEO_PLAYERS     3.6     12764
#
#                     Size    Installs  Type  Price Content Rating  \
# 3665  Varies with device  1000000000  Free    0.0           Teen
# 3666                5.6M     1000000  Free    0.0       Everyone
# 3667                5.4M    10000000  Free    0.0       Everyone
# 3668                2.9M     1000000  Free    0.0       Everyone
# 3669                 25M     1000000  Free    0.0           Teen
#
#                        Genres    Last Updated         Current Ver  \
# 3665  Video Players & Editors  August 2, 2018  Varies with device
# ...

# %%
v1 = video[video.Installs > 1000000]
v1.head()
# Out:
#                           App       Category  Rating   Reviews  \
# 3665                  YouTube  VIDEO_PLAYERS     4.3  25655305
# 3667         Video Downloader  VIDEO_PLAYERS     4.2     59089
# 3670        Motorola FM Radio  VIDEO_PLAYERS     3.9     54807
# 3671  Video Player All Format  VIDEO_PLAYERS     4.8    259003
# 3672         Motorola Gallery  VIDEO_PLAYERS     3.9    121916
#
#                     Size    Installs  Type  Price Content Rating  \
# 3665  Varies with device  1000000000  Free    0.0           Teen
# 3667                5.4M    10000000  Free    0.0       Everyone
# 3670  Varies with device   100000000  Free    0.0       Everyone
# 3671  Varies with device    10000000  Free    0.0       Everyone
# 3672                 23M   100000000  Free    0.0       Everyone
#
#                        Genres      Last Updated         Current Ver  \
# 3665  Video Players & Editors    August 2, 2018  Varies with device
# ...

# %%
videos = pd.pivot_table(data = v1, index =['App','Category'], values=['Rating'])
videos =videos.sort_values('Rating',ascending=False).head(20).reset_index()
videos
# Out:
#                                                   App       Category  Rating
# 0                             Video Player All Format  VIDEO_PLAYERS     4.8
# 1         Video Downloader - for Instagram Repost App  VIDEO_PLAYERS     4.8
# 2   DU Recorder – Screen Recorder, Video Editor, Live  VIDEO_PLAYERS     4.8
# 3   Quik – Free Video Editor for photos, clips, music  VIDEO_PLAYERS     4.7
# 4                        AZ Screen Recorder - No Root  VIDEO_PLAYERS     4.6
# 5                       Inst Download - Video & Photo  VIDEO_PLAYERS     4.6
# 6   YouCut - Video Editor & Video Maker, No Watermark  VIDEO_PLAYERS     4.6
# 7              VivaVideo - Video Editor & Photo Movie  VIDEO_PLAYERS     4.6
# 8   VideoShow-Video Editor, Video Maker, Beauty Ca...  VIDEO_PLAYERS     4.6
# 9                LIKE – Magic Video Maker & Community  VIDEO_PLAYERS     4.6
# 10  PowerDirector Video Editor App: 4K, Slow Mo & ...  VIDEO_PLAYERS     4.5
# ...

# %%
print(v1.groupby('Genres')['Type'].value_counts())
Type_v = v1.groupby('Genres')['Type'].value_counts().unstack()
Type_v
# Out:
# Genres                                 Type
# Video Players & Editors                Free    60
# Video Players & Editors;Creativity     Free     1
# Video Players & Editors;Music & Video  Free     1
# Name: Type, dtype: int64
# Type                                   Free
# Genres
# Video Players & Editors                  60
# Video Players & Editors;Creativity        1
# Video Players & Editors;Music & Video     1

# %%
v_ins = (video.Installs > video.Installs.mean())
v_rev = (video.Reviews > video.Reviews.median())

v_ins_rev = v_ins & v_rev

video[v_ins_rev].sort_values('Rating',ascending=False).head(20)
# Out:
#                                                     App       Category  \
# 4038  DU Recorder – Screen Recorder, Video Editor, Live  VIDEO_PLAYERS
# 4696  VideoShow-Video Editor, Video Maker, Beauty Ca...  VIDEO_PLAYERS
# 4688             VivaVideo - Video Editor & Photo Movie  VIDEO_PLAYERS
# 3693               LIKE – Magic Video Maker & Community  VIDEO_PLAYERS
# 4049                      KineMaster – Pro Video Editor  VIDEO_PLAYERS
# 3690        MiniMovie - Free Video and Slideshow Editor  VIDEO_PLAYERS
# 3703                                          MX Player  VIDEO_PLAYERS
# 3711                                          MX Player  VIDEO_PLAYERS
# 4365                                          MX Player  VIDEO_PLAYERS
# 5612                                          Ringdroid  VIDEO_PLAYERS
# 3675                                    VLC for Android  VIDEO_PLAYERS
# 3691                              Samsung Video Library  VIDEO_PLAYERS
# ...

# %% [markdown]
# # EVENTS

# %%
event = df[df.Category == 'EVENTS']
event.head()
# Out:
#                                                  App Category  Rating  \
# 1004                              All Events in City   EVENTS     4.0
# 1005                      Ticketmaster Event Tickets   EVENTS     4.0
# 1006                                        Reminder   EVENTS     4.5
# 1007                     Birdays - Birthday reminder   EVENTS     4.5
# 1008  StubHub - Tickets to Sports, Concerts & Events   EVENTS     4.0
#
#       Reviews                Size  Installs  Type  Price Content Rating  \
# 1004     3782                9.5M    100000  Free    0.0       Everyone
# 1005    40113                 36M   5000000  Free    0.0       Everyone
# 1006     7074                6.3M    500000  Free    0.0       Everyone
# 1007     2153                5.9M     50000  Free    0.0       Everyone
# 1008    26089  Varies with device   5000000  Free    0.0       Everyone
#
#       Genres       Last Updated         Current Ver         Android Ver
# ...

# %%
ev = event[event.Installs > 1000000]
ev.head()
# Out:
#                                                  App Category  Rating  \
# 1005                      Ticketmaster Event Tickets   EVENTS     4.0
# 1008  StubHub - Tickets to Sports, Concerts & Events   EVENTS     4.0
#
#       Reviews                Size  Installs  Type  Price Content Rating  \
# 1005    40113                 36M   5000000  Free    0.0       Everyone
# 1008    26089  Varies with device   5000000  Free    0.0       Everyone
#
#       Genres    Last Updated         Current Ver         Android Ver
# 1005  Events   July 23, 2018  Varies with device  Varies with device
# 1008  Events  August 2, 2018               4.2.1  Varies with device

# %%
events = pd.pivot_table(data = ev, index =['App','Category'], values=['Rating'])
events = events.reset_index()

# %%
print(ev.groupby('Genres')['Type'].value_counts())
Type_cat = ev.groupby('Genres')['Type'].value_counts().unstack()
Type_cat
# Out:
# Genres  Type
# Events  Free    2
# Name: Type, dtype: int64
# Type    Free
# Genres
# Events     2

# %%
ev_ins = (event.Installs > event.Installs.mean())
ev_rev = (event.Reviews > event.Reviews.median())

ev_ins_rev = ev_ins & ev_rev

event[ev_ins_rev].sort_values('Rating',ascending=False).head(20)
# Out:
#                                                    App Category  Rating  \
# 1014                       Vivid Seats – Event Tickets   EVENTS     4.6
# 1006                                          Reminder   EVENTS     4.5
# 1020   Gametime - Tickets to Sports, Concerts, Theater   EVENTS     4.5
# 1011  SeatGeek – Tickets to Sports, Concerts, Broadway   EVENTS     4.4
# 1005                        Ticketmaster Event Tickets   EVENTS     4.0
# 1008    StubHub - Tickets to Sports, Concerts & Events   EVENTS     4.0
# 1009                                             Fever   EVENTS     4.0
#
#       Reviews                Size  Installs  Type  Price Content Rating  \
# 1014     8232                 53M   1000000  Free    0.0       Everyone
# 1006     7074                6.3M    500000  Free    0.0       Everyone
# 1020     8800                 24M   1000000  Free    0.0       Everyone
# 1011    15558                 26M   1000000  Free    0.0       Everyone
# ...

# %% [markdown]
# # BUSINESS

# %%
bs = df[(df.Category == "BUSINESS")]

# %%
lg1 = bs[(bs.Reviews < 2500) | (bs.Installs <= 10000)]

# %%
for i in lg1.index:
    bs = bs.drop([i] ,axis=0)

# %%
tr =bs.sort_values('Rating',ascending=False).head(50)

# %%
top = tr.sort_values('Installs',ascending=False).head(35)

# %%
final1 =pd.pivot_table(data=top , index =['App','Category'],values="Rating")

# %%
business = final1.nlargest(20,'Rating').reset_index()

# %%
business
# Out:
#                                                   App  Category  Rating
# 0                          Job Search by ZipRecruiter  BUSINESS     4.8
# 1                                         BZ Reminder  BUSINESS     4.7
# 2                      Tiny Scanner - PDF Scanner App  BUSINESS     4.7
# 3                                        Call Blocker  BUSINESS     4.6
# 4                                     Free Resume App  BUSINESS     4.6
# 5                          Square Point of Sale - POS  BUSINESS     4.6
# 6   Curriculum vitae App CV Builder Free Resume Maker  BUSINESS     4.5
# 7                        Fast Scanner : Free PDF Scan  BUSINESS     4.5
# 8                                    Google Analytics  BUSINESS     4.5
# 9       IndiaMART: Search Products, Buy, Sell & Trade  BUSINESS     4.5
# 10                       My Space - Employment Center  BUSINESS     4.5
# 11  Vault-Hide SMS,Pics & Videos,App Lock,Cloud ba...  BUSINESS     4.5
# ...

# %% [markdown]
# # COMMUNICATION

# %%
cm = df[(df.Category == "COMMUNICATION")]

# %%
lg2 = cm[(cm.Reviews < 15000) | (cm.Installs <= 10000)]

# %%
for i in lg2.index:
    cm = cm.drop([i],axis=0)

# %%
tcmr = cm.sort_values('Installs', ascending=False).head(50)

# %%
topcom = tcmr.sort_values('Rating',ascending=False).head(50)

# %%
final2 =pd.pivot_table(data=topcom , index =['App','Category'],values="Rating")

# %%
communication = final2.nlargest(20,'Rating').reset_index()
communication
# Out:
#                                                   App       Category  Rating
# 0               Google Duo - High Quality Video Calls  COMMUNICATION     4.6
# 1                       Opera Mini - fast web browser  COMMUNICATION     4.5
# 2   Truecaller: Caller ID, SMS spam blocking & Dialer  COMMUNICATION     4.5
# 3         UC Browser - Fast Download Private & Secure  COMMUNICATION     4.5
# 4                      Firefox Browser fast & private  COMMUNICATION     4.4
# 5          GO SMS Pro - Messenger, Free Themes, Emoji  COMMUNICATION     4.4
# 6               Messenger Lite: Free Calls & Messages  COMMUNICATION     4.4
# 7                      Opera Browser: Fast and Secure  COMMUNICATION     4.4
# 8                                  WhatsApp Messenger  COMMUNICATION     4.4
# 9                         BBM - Free Calls & Messages  COMMUNICATION     4.3
# 10                                              Gmail  COMMUNICATION     4.3
# ...

# %% [markdown]
# # TRAVEL_AND_LOCAL

# %%
tl = df[(df.Category == "TRAVEL_AND_LOCAL")]

# %%
lg3 = tl[(tl.Reviews < 25000) | (tl.Installs <= 10000)]

# %%
for i in lg3.index:
    tl = tl.drop([i] ,axis=0)

# %%
toptravel = tl.sort_values('Rating',ascending=False).head(50)

# %%
ttl = toptravel.sort_values('Installs', ascending=False).head(35)

# %%
final3 =pd.pivot_table(data=ttl , index =['App','Category'],values="Rating")

# %%
travel = final3.nlargest(20,'Rating').reset_index()

# %%
travel
# Out:
#                                                   App          Category  \
# 0                            Booking.com Travel Deals  TRAVEL_AND_LOCAL
# 1     Where is my Train : Indian Railway & PNR Status  TRAVEL_AND_LOCAL
# 2                         Agoda – Hotel Booking Deals  TRAVEL_AND_LOCAL
# 3                            GasBuddy: Find Cheap Gas  TRAVEL_AND_LOCAL
# 4                         2GIS: directory & navigator  TRAVEL_AND_LOCAL
# 5                                GPS Status & Toolbox  TRAVEL_AND_LOCAL
# 6   Hotels.com: Book Hotel Rooms & Find Vacation D...  TRAVEL_AND_LOCAL
# 7                        KAYAK Flights, Hotels & Cars  TRAVEL_AND_LOCAL
# 8         MAPS.ME – Offline Map and Travel Navigation  TRAVEL_AND_LOCAL
# 9                                          Skyscanner  TRAVEL_AND_LOCAL
# 10        Yatra - Flights, Hotels, Bus, Trains & Cabs  TRAVEL_AND_LOCAL
# 11                                             Airbnb  TRAVEL_AND_LOCAL
# ...

# %% [markdown]
# # ENTERTAINMENT

# %%
en = df[(df.Category == "ENTERTAINMENT")]

# %%
lg4 = en[(en.Reviews < 25000) | (en.Installs <= 10000)]

# %%
for i in lg4.index:
    en = en.drop([i] ,axis=0)

# %%
topent = en.sort_values('Rating',ascending=False).head(50)

# %%
trent = topent.sort_values('Installs', ascending=False).head(40)

# %%
final4 =pd.pivot_table(data=trent , index =['App','Category'],values="Rating")

# %%
entertainment =final4.nlargest(20,'Rating').reset_index()

# %%
entertainment
# Out:
#                                                   App       Category  Rating
# 0                      ColorFul - Adult Coloring Book  ENTERTAINMENT     4.6
# 1                   Fandango Movies - Times + Tickets  ENTERTAINMENT     4.6
# 2      Twitch: Livestream Multiplayer Games & Esports  ENTERTAINMENT     4.6
# 3            Colorfy: Coloring Book for Adults - Free  ENTERTAINMENT     4.5
# 4            Movies by Flixster, with Rotten Tomatoes  ENTERTAINMENT     4.5
# 5                     No.Draw - Colors by Number 2018  ENTERTAINMENT     4.5
# 6                                                 WWE  ENTERTAINMENT     4.5
# 7                                        YouTube Kids  ENTERTAINMENT     4.5
# 8                     ivi - movies and TV shows in HD  ENTERTAINMENT     4.5
# 9                                             Netflix  ENTERTAINMENT     4.4
# 10                                             The CW  ENTERTAINMENT     4.4
# ...

# %% [markdown]
# # WEATHER

# %%
wh = df[(df.Category == "WEATHER")]

# %%
lg5 = wh[(wh.Reviews < 25000) | (wh.Installs <= 10000)]

# %%
for i in lg5.index:
    wh = wh.drop([i] ,axis=0)

# %%
topweather = wh.sort_values('Rating',ascending=False)

# %%
trwh = topweather.sort_values('Installs', ascending=False).head(27)

# %%
final5 =pd.pivot_table(data=trwh , index =['App','Category'],values="Rating")

# %%
weather = final5.nlargest(20,'Rating').reset_index()

# %%
weather
# Out:
#                                                   App Category  Rating
# 0                                    Weather forecast  WEATHER     4.8
# 1                                       Klara weather  WEATHER     4.6
# 2     Storm Radar: Tornado Tracker & Hurricane Alerts  WEATHER     4.6
# 3    GO Weather - Widget, Theme, Wallpaper, Efficient  WEATHER     4.5
# 4                          MyRadar NOAA Weather Radar  WEATHER     4.5
# 5                                           Météociel  WEATHER     4.5
# 6                                           RadarNow!  WEATHER     4.5
# 7                       Weather & Radar Pro - Ad-Free  WEATHER     4.5
# 8                                        Weather Live  WEATHER     4.5
# 9     Weather by WeatherBug: Forecast, Radar & Alerts  WEATHER     4.5
# 10                                     Yandex.Weather  WEATHER     4.5
# 11  AccuWeather: Daily Forecast & Live Weather Rep...  WEATHER     4.4
# ...

# %% [markdown]
# # PARENTING

# %%
pr = df[(df.Category == "PARENTING")]

# %%
lg6 = pr[(pr.Reviews < 1000) | (pr.Installs <= 10000)]

# %%
for i in lg6.index:
    pr = pr.drop([i] ,axis=0)

# %%
topparenting =pr.sort_values('Rating', ascending=False)

# %%
trpr = topparenting.sort_values('Installs', ascending=False)

# %%
final6 =pd.pivot_table(data=trpr ,index =['App','Category'],values="Rating")

# %%
parenting = final6.nlargest(20,'Rating').reset_index()

# %%
parenting
# Out:
#                                                   App   Category  Rating
# 0                            Classical music for baby  PARENTING     4.8
# 1                      Rainbow - Journal & Activities  PARENTING     4.8
# 2                     The first year of a baby's life  PARENTING     4.8
# 3                         Baby Connect (activity log)  PARENTING     4.7
# 4   Family Album Mitene: Private Photo & Video Sha...  PARENTING     4.7
# 5      Pregnancy Tracker & Countdown to Baby Due Date  PARENTING     4.7
# 6      Baby Sleep: White noise lullabies for newborns  PARENTING     4.6
# 7                         BookBaby - Baby Development  PARENTING     4.6
# 8               Development of the child up to a year  PARENTING     4.6
# 9                            Feed Baby - Baby Tracker  PARENTING     4.5
# 10                          My Child from eDziecko.pl  PARENTING     4.5
# 11                                       Baby Monitor  PARENTING     4.4
# ...

# %% [markdown]
# # SPORTS

# %%
values =['TOOLS','SPORTS','PHOTOGRAPHY','EDUCATION','ART_AND_DESIGN','COMICS']
my = df[(df.Category.isin(values))]

# %%
my.Installs = my.Installs.replace('[+,]','',regex=True)
my.Installs = my.Installs.astype("int64")

# %%
my = my.drop(columns=['Last Updated','Current Ver','Android Ver'])

# %%
my.Reviews = my.Reviews.astype('int64')

# %%
my.Rating = my.Rating.fillna(0)

# %%
sport = my[(my.Category == 'SPORTS')]

# %%
drops = sport[(sport.Installs <=100000) | (sport.Rating <=4.0)]

# %%
for i in drops.index:
    sport = sport.drop([i],axis=0)

# %%
inst = sport.sort_values('Installs',ascending=False).head(50)

# %%
inst = inst.drop_duplicates()

# %%
rate = inst.sort_values('Rating',ascending=False).head(30)

# %%
All = pd.pivot_table(data = rate, index =['App','Category'], values= ["Rating","Reviews",'Installs'] )

# %%
topsport = All.reset_index()

# %%
sports = topsport.drop(columns=['Installs','Reviews'])
sports
# Out:
#                                                   App Category  Rating
# 0                             365Scores - Live Scores   SPORTS     4.6
# 1                                         8 Ball Pool   SPORTS     4.5
# 2                 All Football - Latest News & Videos   SPORTS     4.6
# 3                                    Basketball Stars   SPORTS     4.4
# 4               Cricbuzz - Live Cricket Scores & News   SPORTS     4.5
# 5                            Dream League Soccer 2018   SPORTS     4.6
# 6                                      EA SPORTS UFC®   SPORTS     4.5
# 7                         FotMob - Live Soccer Scores   SPORTS     4.7
# 8                       LiveScore: Live Sport Updates   SPORTS     4.4
# 9                                         Mobile Kick   SPORTS     4.3
# 10                                                NBA   SPORTS     4.4
# 11                         NBA LIVE Mobile Basketball   SPORTS     4.4
# ...

# %% [markdown]
# # EDUCATION

# %%
edu = my[(my.Category == 'EDUCATION')]

# %%
ed = edu[(edu.Rating < 4.0) | (edu.Installs <=100000)]

# %%
for i in ed.index:
    edu = edu.drop([i],axis=0)

# %%
edui = edu.sort_values('Installs',ascending=False).head(50)

# %%
edui = edui.drop_duplicates()

# %%
edur = edui.sort_values('Rating',ascending=False).head(30)

# %%
topedu = pd.pivot_table(data= edur,index =['App','Category'], values=['Rating','Installs','Reviews'])

# %%
topedu = topedu.reset_index()

# %%
education = topedu.drop(columns=['Installs','Reviews'])

# %%
education = education.nlargest(21,'Rating')
education
# Out:
#                                                   App   Category  Rating
# 10                         Learn English with Wlingua  EDUCATION     4.7
# 11  Learn languages, grammar & vocabulary with Mem...  EDUCATION     4.7
# 3                      Duolingo: Learn Languages Free  EDUCATION     4.7
# 4                              English with Lingualeo  EDUCATION     4.7
# 7                                        Khan Academy  EDUCATION     4.6
# 9                            Learn English Words Free  EDUCATION     4.6
# 16   Quizlet: Learn Languages & Vocab with Flashcards  EDUCATION     4.6
# 19                                                TED  EDUCATION     4.6
# 17                       Remind: School Communication  EDUCATION     4.5
# 12                                        Math Tricks  EDUCATION     4.5
# 18  Rosetta Stone: Learn to Speak & Read New Langu...  EDUCATION     4.5
# 15                             Princess Coloring Book  EDUCATION     4.5
# ...

# %% [markdown]
# # ART_AND_DESIGN

# %%
art = my[(my.Category == 'ART_AND_DESIGN')]

# %%
ar = art[(art.Rating < 4.0) | (art.Installs <=100000)]

# %%
for i in ar.index:
    art = art.drop([i],axis =0)

# %%
arti = art.sort_values('Installs',ascending= False).head(20)

# %%
artr = arti.sort_values('Rating',ascending=False).head(15)

# %%
topart = pd.pivot_table(data = artr, index =['App','Category'], values = ['Rating','Installs','Reviews'])

# %%
topart = topart.nlargest(14,'Rating')
topart = topart.drop(columns=['Installs','Reviews'])
art_design = topart.reset_index()
art_design
# Out:
#                                                   App        Category  Rating
# 0   Canva: Poster, banner, card maker & graphic de...  ART_AND_DESIGN     4.7
# 1                       Colorfit - Drawing & Coloring  ART_AND_DESIGN     4.7
# 2        Photo Designer - Write your name with shapes  ART_AND_DESIGN     4.7
# 3             Superheroes Wallpapers | 4K Backgrounds  ART_AND_DESIGN     4.7
# 4   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 5      UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN     4.7
# 6                                        ibis Paint X  ART_AND_DESIGN     4.6
# 7                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9             Name Art Photo Editor - Focus n Filters  ART_AND_DESIGN     4.4
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %% [markdown]
# # COMICS

# %%
com = my[my.Category == 'COMICS']

# %%
co = com[(com.Rating < 4.0)| (com.Installs <=100000)]

# %%
for i in co.index:
    com = com.drop([i],axis =0)

# %%
comi = com.sort_values('Installs',ascending= False).head(20)

# %%
comr = comi.sort_values('Rating',ascending=False).head(15)

# %%
topcom = pd.pivot_table(data= comr , index =['App','Category'], values=['Rating','Installs','Reviews'])

# %%
topcom = topcom.nlargest(14,'Rating')
topcom = topcom.drop(columns=['Installs','Reviews'])
comics = topcom.reset_index()

# %%
comics = comics.drop([2],axis = 0)
comics
# Out:
#                                                   App Category  Rating
# 0                                           WebComics   COMICS     4.8
# 1   GANMA! - All original stories free of charge f...   COMICS     4.7
# 3            Manga Master - Best manga & comic reader   COMICS     4.6
# 4   Buff Thun - Daily Free Webtoon / Comics / Web ...   COMICS     4.5
# 5                          LINE WEBTOON - Free Comics   COMICS     4.5
# 6                                    Narrator's Voice   COMICS     4.5
# 7                 Tapas – Comics, Novels, and Stories   COMICS     4.5
# 8                      Manga Rock - Best Manga Reader   COMICS     4.4
# 9                                        Memes Button   COMICS     4.4
# 10                                     Perfect Viewer   COMICS     4.4
# 11                 pixiv comic - everyone's manga app   COMICS     4.4
# 12                                          DC Comics   COMICS     4.2
# ...

# %% [markdown]
# # TOOLS

# %%
tool = my[(my.Category == 'TOOLS')]

# %%
to = tool[(tool.Rating < 4.0) | (tool.Installs <=100000) | (tool.Reviews <= 50000)]

# %%
for i in to.index:
    tool = tool.drop([i], axis = 0)

# %%
tooli = tool.sort_values('Installs',ascending=False).head(50)

# %%
toolr = tooli.sort_values('Rating', ascending= False).head(35)

# %%
topri = pd.pivot_table(data= toolr , index =['App','Category'], values='Rating')

# %%
tools = topri.nlargest(25,'Rating').reset_index()
tools
# Out:
#                                                   App Category  Rating
# 0                         Brightest Flashlight Free ®    TOOLS     4.7
# 1             Clean Master- Space Cleaner & Antivirus    TOOLS     4.7
# 2   Kaspersky Mobile Antivirus: AppLock & Web Secu...    TOOLS     4.7
# 3   Security Master - Antivirus, VPN, AppLock, Boo...    TOOLS     4.7
# 4     360 Security - Free Antivirus, Booster, Cleaner    TOOLS     4.6
# 5                     CM Locker - Security Lockscreen    TOOLS     4.6
# 6               Clean Master Lite - For Low-End Phone    TOOLS     4.6
# 7                                        File Manager    TOOLS     4.6
# 8   Master for Minecraft(Pocket Edition)-Mod Launcher    TOOLS     4.6
# 9                          SHAREit - Transfer & Share    TOOLS     4.6
# 10                      Video Downloader for Facebook    TOOLS     4.6
# 11            AVG AntiVirus 2018 for Android Security    TOOLS     4.5
# ...

# %% [markdown]
# # PHOTOGRAPHY

# %%
pic = my[(my.Category == 'PHOTOGRAPHY')]

# %%
photo = pic[(pic.Installs <= 100000) | (pic.Rating < 4.0) | (pic.Reviews <= 20000)]

# %%
for i in photo.index:
    pic = pic.drop([i], axis = 0)

# %%
pici = pic.sort_values('Installs', ascending= False).head(60)

# %%
picr = pici.sort_values('Rating',ascending=False).head(35)

# %%
toppic = pd.pivot_table(data= picr,index =['App','Category'], values=['Installs','Rating','Reviews'])

# %%
toppic = toppic.nlargest(20,'Installs').reset_index()
photography= toppic.drop(columns=['Installs','Reviews'])
photography
# Out:
#                                                   App     Category  Rating
# 0                                       Google Photos  PHOTOGRAPHY     4.5
# 1                       B612 - Beauty & Filter Camera  PHOTOGRAPHY     4.4
# 2      BeautyPlus - Easy Photo Editor & Selfie Camera  PHOTOGRAPHY     4.4
# 3   Candy Camera - selfie, beauty camera, photo ed...  PHOTOGRAPHY     4.4
# 4   Cymera Camera- Photo Editor, Filter,Collage,La...  PHOTOGRAPHY     4.4
# 5                      Photo Editor Collage Maker Pro  PHOTOGRAPHY     4.5
# 6   PhotoGrid: Video & Pic Collage Maker, Photo Ed...  PHOTOGRAPHY     4.6
# 7    PicsArt Photo Studio: Collage Maker & Pic Editor  PHOTOGRAPHY     4.5
# 8      S Photo Editor - Collage Maker , Photo Collage  PHOTOGRAPHY     4.4
# 9   Sweet Selfie - selfie camera, beauty cam, phot...  PHOTOGRAPHY     4.6
# 10             YouCam Makeup - Magic Selfie Makeovers  PHOTOGRAPHY     4.6
# ...

# %% [markdown]
# # MEDICAL

# %%
med=df[(df.Category == 'MEDICAL')]
med
# Out:
#                               App Category  Rating  Reviews  \
# 2243   Monash Uni Low FODMAP Diet  MEDICAL     4.2     1135
# 2244           iBP Blood Pressure  MEDICAL     4.4      578
# 2245                    Pedi STAT  MEDICAL     4.6      129
# 2246                 ASCCP Mobile  MEDICAL     4.5       63
# 2247       Journal Club: Medicine  MEDICAL     4.8      216
# ...                           ...      ...     ...      ...
# 10730                 FP Notebook  MEDICAL     4.5      410
# 10768                        AAFP  MEDICAL     3.8       63
# 10806             SnakeBite911 FR  MEDICAL     0.0        1
# 10824                   Cardio-FR  MEDICAL     0.0       67
# 10838      Parkinson Exercices FR  MEDICAL     0.0        3
#
#                      Size  Installs  Type  Price Content Rating   Genres  \
# 2243                  12M    100000  Paid   9.00       Everyone  Medical
# 2244                 704k     10000  Paid   0.99       Everyone  Medical
# ...

# %%
unrated_med=med[ ((med.Rating >= 4.0) & (med.Reviews <= 1000)) | (med.Installs <=10000) ]

# %%
for i in unrated_med.index:
    med = med.drop([i],axis = 0)

# %%
top=med.sort_values('Rating',ascending=False)

# %%
top_med_install=top.sort_values('Installs',ascending=False).head(30)

# %%
medical_app = pd.pivot_table(data=top_med_install,index =['App','Category'],values=['Rating'])

# %%
medical = medical_app.sort_values('Rating',ascending=False).reset_index()

# %%
medical
# Out:
#                                                   App Category  Rating
# 0                                      Period Tracker  MEDICAL     4.9
# 1                      GoodRx Drug Prices and Coupons  MEDICAL     4.8
# 2                              Pregnancy Week By Week  MEDICAL     4.8
# 3                Pregnancy Calculator and Tracker app  MEDICAL     4.8
# 4    Ovia Pregnancy Tracker & Baby Countdown Calendar  MEDICAL     4.8
# 5       Ovia Fertility Tracker & Ovulation Calculator  MEDICAL     4.8
# 6                             Ada - Your Health Guide  MEDICAL     4.7
# 7                        My Calendar - Period Tracker  MEDICAL     4.7
# 8                          1800 Contacts - Lens Store  MEDICAL     4.7
# 9                                    Doctor On Demand  MEDICAL     4.7
# 10                                    FollowMyHealth®  MEDICAL     4.6
# 11  mySugr: the blood sugar tracker made just for you  MEDICAL     4.6
# ...

# %% [markdown]
# # LIFESTYLE

# %%
life=df[(df.Category == 'LIFESTYLE')]
life
# Out:
#                                                      App   Category  Rating  \
# 1562                          Dollhouse Decorating Games  LIFESTYLE     4.1
# 1563                                           metroZONE  LIFESTYLE     4.1
# 1564                              Easy Hair Style Design  LIFESTYLE     4.3
# 1565                      Talking Babsy Baby: Baby Games  LIFESTYLE     4.0
# 1566   Black Wallpaper, AMOLED, Dark Background: Darkify  LIFESTYLE     4.6
# ...                                                  ...        ...     ...
# 10773                                           FQ India  LIFESTYLE     0.0
# 10797                              Fuel Rewards® program  LIFESTYLE     4.6
# 10805                                      Scoreboard FR  LIFESTYLE     4.3
# 10808                                 lesparticuliers.fr  LIFESTYLE     0.0
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
# ...

# %%
unrated_life=life[ ((life.Rating >= 4.5) & (life.Reviews <= 10000))  | (life.Installs <= 50000)]

# %%
for j in unrated_life.index:
    life = life.drop([j],axis = 0)

# %%
life=life[(life.Rating >= 4.5)]

# %%
top_life=life.sort_values('Rating',ascending=False)

# %%
top_life_install=top_life.sort_values('Installs',ascending=False).head(20)

# %%
lifestyles_app = pd.pivot_table(data=top_life_install,index =['App','Category'],values=['Rating'])

# %%
lifestyles = lifestyles_app.sort_values('Rating',ascending=False).reset_index()
lifestyles
# Out:
#                                                   App   Category  Rating
# 0                                       Nature Sounds  LIFESTYLE     4.8
# 1                                     The Holy Rosary  LIFESTYLE     4.7
# 2                                     Daily Horoscope  LIFESTYLE     4.7
# 3      Muslim Pro - Prayer Times, Azan, Quran & Qibla  LIFESTYLE     4.7
# 4                       Al-Moazin Lite (Prayer Times)  LIFESTYLE     4.6
# 5                         Big Days - Events Countdown  LIFESTYLE     4.6
# 6                            Relax Rain ~ Rain Sounds  LIFESTYLE     4.6
# 7   Notes : Colorful Notepad Note,To Do,Reminder,Memo  LIFESTYLE     4.6
# 8                         Live 4D Results ! (MY & SG)  LIFESTYLE     4.6
# 9                            Journey - Diary, Journal  LIFESTYLE     4.6
# 10                           JOANN - Crafts & Coupons  LIFESTYLE     4.6
# 11  Horoscopes – Daily Zodiac Horoscope and Astrology  LIFESTYLE     4.6
# ...

# %% [markdown]
# # DATING

# %%
date=df[(df.Category == 'DATING')]
date
# Out:
#                                                    App Category  Rating  \
# 476                          Moco+ - Chat, Meet People   DATING     4.2
# 477                                         Calculator   DATING     2.6
# 478                                  Truth or Dare Pro   DATING     0.0
# 479    Private Dating, Hide App- Blue for PrivacyHider   DATING     0.0
# 480                               Ad Blocker for SayHi   DATING     0.0
# ...                                                ...      ...     ...
# 7077                    Zoosk Dating App: Meet Singles   DATING     4.0
# 7303                    Chat Anónimo Gratis Español CG   DATING     3.5
# 10045                                 Get Over Your Ex   DATING     4.1
# 10168                   FEABIE: Feedees, BBW, BHM & FA   DATING     3.7
# 10715                               FarmersOnly Dating   DATING     3.0
#
#        Reviews                Size  Installs  Type  Price Content Rating  \
# ...

# %%
unrated_date=date[ ((date.Rating >= 4.5) & (date.Reviews <= 10000))  | (date.Installs <= 50000)]

# %%
for k in unrated_date.index:
    date = date.drop([k],axis=0)

# %%
date=date[(date.Rating >= 4.0)]

# %%
top_date=date.sort_values('Rating',ascending=False)

# %%
top_date_Installs=top_date.sort_values('Installs',ascending=False)

# %%
Dating_app = pd.pivot_table(data=top_date_Installs, index =['App','Category'],values=['Rating'])

# %%
Dating= Dating_app.sort_values('Rating',ascending=False).reset_index().head(20)

# %%
Dating
# Out:
#                                                   App Category  Rating
# 0         Dating for 50 plus Mature Singles – FINALLY   DATING     4.6
# 1                            iPair-Meet, Chat, Dating   DATING     4.5
# 2             Casual Dating & Adult Singles - Joyride   DATING     4.5
# 3             Find Real Love — YouLove Premium Dating   DATING     4.5
# 4   TryDate - Free Online Dating App, Chat Meet Ad...   DATING     4.4
# 5                    Once - Quality Matches Every day   DATING     4.4
# 6   Free Dating App & Flirt Chat - Match with Singles   DATING     4.4
# 7                 2Date Dating App, Love and matching   DATING     4.4
# 8   Hide App, Private Dating, Safe Chat - PrivacyH...   DATING     4.4
# 9                         BBW Dating & Plus Size Chat   DATING     4.4
# 10                 Chat Rooms, Avatars, Date - Galaxy   DATING     4.3
# 11  Mingle2 - Free Online Dating & Singles Chat Rooms   DATING     4.3
# ...

# %% [markdown]
# # FOOD_AND_DRINK

# %%
food=df[(df.Category == 'FOOD_AND_DRINK')]
food
# Out:
#                                                      App        Category  \
# 1176                                          McDonald's  FOOD_AND_DRINK
# 1177                               Easy and Fast Recipes  FOOD_AND_DRINK
# 1178   Cookpad - FREE recipe search makes fun cooking...  FOOD_AND_DRINK
# 1179   DELISH KITCHEN - FREE recipe movies make food ...  FOOD_AND_DRINK
# 1180            Sumine side dish - dish recipe side dish  FOOD_AND_DRINK
# ...                                                  ...             ...
# 9487                  3D Metal Piano Keys Keyboard Theme  FOOD_AND_DRINK
# 9540                        El Pollo Loco - Loco Rewards  FOOD_AND_DRINK
# 9819                                          ¿Es Vegan?  FOOD_AND_DRINK
# 9834                         Recettes Faciles et Rapides  FOOD_AND_DRINK
# 10347                           Santa Fe Espresso & News  FOOD_AND_DRINK
#
#        Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %%
unrated_food=food[ ((food.Rating >= 4.5) & (food.Reviews <= 10000))  | (food.Installs <= 50000)]

# %%
for a in unrated_food.index:
    food= food.drop([a],axis=0)

# %%
food=food[(food.Rating >= 4.0)]

# %%
top_food=food.sort_values('Rating',ascending=False)

# %%
top_food_Installs=top_food.sort_values('Installs',ascending=False)

# %%
food_app = pd.pivot_table(data=top_food_Installs, index =['App','Category'],values=['Rating']).head(20)

# %%
food = food_app.sort_values('Rating',ascending=False).reset_index().head(20)

# %%
food
# Out:
#                                                   App        Category  Rating
# 0                            BeyondMenu Food Delivery  FOOD_AND_DRINK     4.7
# 1                                  Domino's Pizza USA  FOOD_AND_DRINK     4.7
# 2                                   Delicious Recipes  FOOD_AND_DRINK     4.7
# 3   DELISH KITCHEN - FREE recipe movies make food ...  FOOD_AND_DRINK     4.6
# 4                                             Cookpad  FOOD_AND_DRINK     4.5
# 5                            DoorDash - Food Delivery  FOOD_AND_DRINK     4.5
# 6                           Allrecipes Dinner Spinner  FOOD_AND_DRINK     4.5
# 7                                      Delivery yogi.  FOOD_AND_DRINK     4.4
# 8                  3D Metal Piano Keys Keyboard Theme  FOOD_AND_DRINK     4.4
# 9                                         Chick-fil-A  FOOD_AND_DRINK     4.3
# 10  Delivery Club-food delivery: pizza, sushi, bur...  FOOD_AND_DRINK     4.3
# ...

# %% [markdown]
# # LIBRARIES_AND_DEMO

# %%
Library=df[(df.Category == 'LIBRARIES_AND_DEMO')]
Library
# Out:
#                                                App            Category  \
# 1514                        Public Digital Library  LIBRARIES_AND_DEMO
# 1515                                        Quotes  LIBRARIES_AND_DEMO
# 1516   Best New Ringtones 2018 Free 🔥 For Android™  LIBRARIES_AND_DEMO
# 1517                                 Lamp detector  LIBRARIES_AND_DEMO
# 1518                                        SUDOKU  LIBRARIES_AND_DEMO
# ...                                            ...                 ...
# 8203                                  db.Mobil App  LIBRARIES_AND_DEMO
# 9790                          ES Chromecast plugin  LIBRARIES_AND_DEMO
# 9893                             EU CBRNE Glossary  LIBRARIES_AND_DEMO
# 10290                 FD VR - Virtual App Launcher  LIBRARIES_AND_DEMO
# 10729                      MX Player Codec (ARMv7)  LIBRARIES_AND_DEMO
#
#        Rating  Reviews                Size  Installs  Type  Price  \
# ...

# %%
unrated_Library=Library[ ((Library.Rating >= 4.5) & (Library.Reviews <= 10000))  | (Library.Installs <= 50000)]

# %%
for b in unrated_Library.index:
    Library= Library.drop([b],axis=0)

# %%
Library=Library[(Library.Rating >= 4.0)]

# %%
top_Library=Library.sort_values('Rating',ascending=False)

# %%
top_Library_Installs=top_Library.sort_values('Installs',ascending=False)

# %%
Library = pd.pivot_table(data=top_Library_Installs, index =['App','Category'],values=['Rating']).reset_index().head(20)

# %%
Library
# Out:
#                                   App            Category  Rating
# 0                AZ Plugin 2 (newest)  LIBRARIES_AND_DEMO     4.2
# 1                     Barcode Scanner  LIBRARIES_AND_DEMO     4.2
# 2                           Cardboard  LIBRARIES_AND_DEMO     4.2
# 3       Cool Popular Ringtones 2018 🔥  LIBRARIES_AND_DEMO     4.5
# 4                ES Chromecast plugin  LIBRARIES_AND_DEMO     4.2
# 5        FD VR - Virtual App Launcher  LIBRARIES_AND_DEMO     4.1
# 6             MX Player Codec (ARMv7)  LIBRARIES_AND_DEMO     4.3
# 7                Market Update Helper  LIBRARIES_AND_DEMO     4.1
# 8                  New Ringtones 2018  LIBRARIES_AND_DEMO     4.1
# 9    Pink Water Sakura Keyboard Theme  LIBRARIES_AND_DEMO     4.3
# 10                             SUDOKU  LIBRARIES_AND_DEMO     4.1
# 11  Top Popular Ringtones 2018 Free 🔥  LIBRARIES_AND_DEMO     4.4
# 12                          Wifi Test  LIBRARIES_AND_DEMO     4.0
# ...

# %% [markdown]
# # GAME

# %%
a = df[df.Category == 'GAME']

a1 = a[a.Reviews > 25000]
a2 = a1[a.Installs > 100000]

a3 = pd.pivot_table(data = a2, index =['App','Category'], values = ['Reviews','Rating','Installs'])

a3.nlargest(20,'Installs')

a4 = a3.drop(['Installs','Reviews'], axis=1)

Top_Game = a4
game = Top_Game.head(20).reset_index()
game
# Out:
#                                      App Category  Rating
# 0        1LINE – One Line with One Touch     GAME     4.6
# 1                             4 in a row     GAME     4.3
# 2                            8 Ball Pool     GAME     4.5
# 3         AE 3D MOTOR :Racing Games Free     GAME     4.2
# 4          AE Bingo: Offline Bingo Games     GAME     4.4
# 5             AE Coin Mania : Arcade Fun     GAME     4.3
# 6                  ARK: Survival Evolved     GAME     3.8
# 7                                Agar.io     GAME     4.2
# 8                       Alto's Adventure     GAME     4.6
# 9               Angelo Rules - Crazy day     GAME     3.9
# 10             Anger of stick 5 : zombie     GAME     4.5
# 11                         Angry Birds 2     GAME     4.6
# 12                   Angry Birds Classic     GAME     4.4
# 13                   Angry Birds Friends     GAME     4.2
# 14                       Angry Birds Go!     GAME     4.2
# ...

# %% [markdown]
# # HEALTH_AND_FITNESS

# %%
b = df[df.Category == 'HEALTH_AND_FITNESS']

b1 = b[b.Reviews > 50000]
b2 = b1[b.Installs > 1000000]

b3 = pd.pivot_table(data = b2, index =['App','Category'], values = ['Reviews','Rating','Installs'])

b3.nlargest(20,'Installs')

b4 = b3.drop(['Installs','Reviews'], axis=1)

Top_HEALTH_AND_FITNESS = b4
health = Top_HEALTH_AND_FITNESS.head(20).reset_index()
health
# Out:
#                                                   App            Category  \
# 0          30 Day Fitness Challenge - Workout at Home  HEALTH_AND_FITNESS
# 1                                    7 Minute Workout  HEALTH_AND_FITNESS
# 2                        8fit Workouts & Meal Planner  HEALTH_AND_FITNESS
# 3      Abs Workout - Burn Belly Fat with No Equipment  HEALTH_AND_FITNESS
# 4                       Calm - Meditate, Sleep, Relax  HEALTH_AND_FITNESS
# 5                      Calorie Counter - MyFitnessPal  HEALTH_AND_FITNESS
# 6                        Calorie Counter by FatSecret  HEALTH_AND_FITNESS
# 7   Daily Workouts - Exercise Fitness Routine Trainer  HEALTH_AND_FITNESS
# 8                     Daily Yoga - Yoga Fitness Plans  HEALTH_AND_FITNESS
# 9                       Endomondo - Running & Walking  HEALTH_AND_FITNESS
# 10      Fabulous: Motivate Me! Meditate, Relax, Sleep  HEALTH_AND_FITNESS
# 11                                             Fitbit  HEALTH_AND_FITNESS
# ...

# %% [markdown]
# # SHOPPING

# %%
c = df[df.Category == 'SHOPPING']

c1 = c[c.Reviews > 50000]
c2 = c1[c.Installs > 1000000]

c3 = pd.pivot_table(data = c2, index =['App','Category'], values = ['Reviews','Rating','Installs'])

c3.nlargest(20,'Installs').head()

c4 = c3.drop(['Installs','Reviews'], axis=1)

Top_SHOPPING = c4
shopping = Top_SHOPPING.head(20).reset_index()
shopping
# Out:
#                                                  App  Category  Rating
# 0                                               ASOS  SHOPPING     4.7
# 1       AliExpress - Smarter Shopping, Better Living  SHOPPING     4.6
# 2                                    Amazon Shopping  SHOPPING     4.3
# 3                                 Amazon for Tablets  SHOPPING     4.0
# 4                                           Best Buy  SHOPPING     4.4
# 5                         Blibli.com Online Shopping  SHOPPING     4.2
# 6                    Bukalapak - Buy and Sell Online  SHOPPING     4.4
# 7                     Buscapé - Offers and discounts  SHOPPING     4.4
# 8                     Carousell: Snap-Sell, Chat-Buy  SHOPPING     4.3
# 9                       Checkout 51: Grocery coupons  SHOPPING     4.1
# 10           Club Factory Everything, Unbeaten Price  SHOPPING     4.2
# 11                                           Coupang  SHOPPING     4.6
# ...

# %% [markdown]
# # BOOKS_AND_REFERENCE

# %%
d = df[df.Category == 'BOOKS_AND_REFERENCE']

d1 = d[d.Reviews > 50000]
d2 = d1[d.Installs > 1000000]


d3 = pd.pivot_table(data = d2, index =['App','Category'], values = ['Reviews','Rating','Installs'])

d3.nlargest(20,'Installs').head()

d4 = d3.drop(['Installs','Reviews'], axis=1)

Top_BOOKS_AND_REFERENCE = d4
books = Top_BOOKS_AND_REFERENCE.head(20).reset_index()
books
# Out:
#                                                   App             Category  \
# 0                 50000 Free eBooks & Free AudioBooks  BOOKS_AND_REFERENCE
# 1       Al Quran : EAlim - Translations & MP3 Offline  BOOKS_AND_REFERENCE
# 2                                  Al Quran Indonesia  BOOKS_AND_REFERENCE
# 3                           Al'Quran Bahasa Indonesia  BOOKS_AND_REFERENCE
# 4                                     Al-Quran (Free)  BOOKS_AND_REFERENCE
# 5                      AlReader -any text book reader  BOOKS_AND_REFERENCE
# 6                                  Aldiko Book Reader  BOOKS_AND_REFERENCE
# 7                                       Amazon Kindle  BOOKS_AND_REFERENCE
# 8                                            Ancestry  BOOKS_AND_REFERENCE
# 9                             Audiobooks from Audible  BOOKS_AND_REFERENCE
# 10                                              Bible  BOOKS_AND_REFERENCE
# ...

# %% [markdown]
# # AUTO_AND_VEHICLES

# %%
e = df[df.Category == 'AUTO_AND_VEHICLES']

e1 = e[e.Reviews > 5000]
e2 = e1[e.Installs > 10000]

e3 = pd.pivot_table(data = e2, index =['App','Category'], values = ['Reviews','Rating','Installs'])

e.nlargest(20,'Installs')

e4 = e3.drop(['Installs','Reviews'], axis=1)

Top_AUTO_AND_VEHICLES = e4
auto = Top_AUTO_AND_VEHICLES.head(20).reset_index()
auto
# Out:
#                                                   App           Category  \
# 0       Android Auto - Maps, Media, Messaging & Voice  AUTO_AND_VEHICLES
# 1                       AutoScout24 - used car finder  AUTO_AND_VEHICLES
# 2         AutoScout24 Switzerland – Find your new car  AUTO_AND_VEHICLES
# 3                      CDL Practice Test 2018 Edition  AUTO_AND_VEHICLES
# 4   CarMax – Cars for Sale: Search Used Car Inventory  AUTO_AND_VEHICLES
# 5               DMV Permit Practice Test 2018 Edition  AUTO_AND_VEHICLES
# 6   Fines of the State Traffic Safety Inspectorate...  AUTO_AND_VEHICLES
# 7                             Fuelio: Gas log & costs  AUTO_AND_VEHICLES
# 8                          PakWheels: Buy & Sell Cars  AUTO_AND_VEHICLES
# 9                             Tickets + PDA 2018 Exam  AUTO_AND_VEHICLES
# 10  Tickets SDA 2018 and Exam from the State Traff...  AUTO_AND_VEHICLES
# 11                         Tickets SDA 2019 + Exam RF  AUTO_AND_VEHICLES
# ...

# %%
dt = pd.concat([beauty,books,auto,game,social,productivity,personalization,housing,maps,business,
                communication,travel,entertainment,weather,parenting,sports,education,art_design,
                comics,tools,photography,medical,lifestyles,Dating,food,Library,
                health,shopping,family,events,finance,videos,NEWS],axis=0)

# %%
dt.reset_index().head()
# Out:
#    index                                                App Category  Rating
# 0      0                      Beauty Camera - Selfie Camera   BEAUTY     4.0
# 1      1                       Best Hairstyles step by step   BEAUTY     4.5
# 2      2                                 Filters for Selfie   BEAUTY     4.3
# 3      3                                        Ulta Beauty   BEAUTY     4.7
# 4      4  Sephora: Skin Care, Beauty Makeup & Fragrance ...   BEAUTY     4.5

# %%
df =  df.set_index("App")
df
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating  Reviews  \
# App
# ...

# %%
def cat():
    print(df.Category.unique())
    cat = input("Enter Category --")
    r = dt[(dt['Category']== cat)]
    print(r)
    
    print("")
    a = input("Enter App name")
    
    print((df.loc[a]).T)

# %%
cat()
# Out:
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION']
# Enter Category --SOCIAL
#                                                  App Category  Rating
# 0                                          Instagram   SOCIAL     4.5
# 1                                            Google+   SOCIAL     4.2
# 2                                           Facebook   SOCIAL     4.1
# 3                                           Snapchat   SOCIAL     4.0
# 4                                      Facebook Lite   SOCIAL     4.3
# ...
